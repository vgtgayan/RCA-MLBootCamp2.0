# %%
import pandas as pd

# %%
df  = pd.read_csv("first_draft.csv")
df
# Out:
#                     key                 l1       l2   l3  \
# P10049895-138085  Verdi               FSDB      NaN  NaN
# P10049895-138082  Verdi  Interactive Debug      NaN  NaN
# P10049895-138081  Verdi               FSDB  Utility  NaN
# P10049895-138080  Verdi               FSDB  Utility  NaN
# P10049895-138078  Verdi    Low Power Debug      NaN  NaN
# ...                 ...                ...      ...  ...
# P10049895-12475   Verdi  Interactive Debug      NaN  NaN
# P10049895-12313   Verdi          OneSearch      NaN  NaN
# P10049895-11884   Verdi             nTrace      NaN  NaN
# P10049895-11882   Verdi             nTrace      NaN  NaN
# P10049895-11631   Verdi    C/SystemC Debug      NaN  NaN
#
#                                                                  l4  \
# P10049895-138085  BRCM 9550: Protocol Analyzer bogus RT error du...
# P10049895-138082  Intel-LNL Verdi is hanging when loading one fi...
# P10049895-138081  [fsdb2saif] One bit integer turned to be 32 bi...
# ...

# %%
df.columns
# Out:
# Index(['key', 'l1', 'l2', 'l3', 'l4', 'summary', 'description', 'labels',
#        'logo', 'category', 'customer_severity', 'is_safty_related_issue'],
#       dtype='object')

# %% [markdown]
# ## Exploratary Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3992 entries, P10049895-138085 to P10049895-11631
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   key                     3992 non-null   object
#  1   l1                      3992 non-null   object
#  2   l2                      1481 non-null   object
#  3   l3                      86 non-null     object
#  4   l4                      3992 non-null   object
#  5   summary                 3992 non-null   object
#  6   description             510 non-null    object
#  7   labels                  3992 non-null   object
#  8   logo                    3992 non-null   object
#  9   category                3992 non-null   object
#  10  customer_severity       661 non-null    object
#  11  is_safty_related_issue  3992 non-null   object
# dtypes: object(12)
# memory usage: 405.4+ KB

# %%
df.isnull().sum()
# Out:
# key                          0
# l1                           0
# l2                        2511
# l3                        3906
# l4                           0
# summary                      0
# description               3482
# labels                       0
# logo                         0
# category                     0
# customer_severity         3331
# is_safty_related_issue       0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#           key                   l1       l2         l3  \
# count    3992                 3992     1481         86
# unique      1                   43       75         15
# top     Verdi  Compiler (UFE flow)  elabcom  Exclusion
# freq     3992                  487      240         16
#
#                                                        l4  \
# count                                                3992
# unique                                               3962
# top     java is invoked from PATH  should invoke from ...
# freq                                                    3
#
#                                                   summary description  \
# count                                                3992         510
# unique                                               3959         242
# top     While creating power map  1. cannot stop creat...    NEED_ETA
# freq                                                    3          72
#
# ...

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# ### L2
